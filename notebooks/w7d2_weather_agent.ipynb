# %%
# !pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.75.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.75.0-py3-none-any.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.2/388.2 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.75.0

# %%
import anthropic
from anthropic.types import MessageParam
from google.colab import userdata

# %% [markdown]
# ## Tools

# %%
weather_tool = {
    "name": "get_current_weather",
    "description": "Get the current weather for the given location. The location should be a city with state/country. "
    + "Use this tool if the user needs to know the current weather for a location. "
    + "The tool will return the current temperature in the given unit. If the unit is not provided, it will default to celsius.",
    "input_schema": {
        "type": "object",
        "properties": {
            "location": {
                "type": "string",
                "description": "The city and state/country to get the weather for. e.g. 'New York, NY', 'San Francisco, CA', 'London, UK'",
            },
            "unit": {
                "type": "string",
                "enum": ["celsius", "fahrenheit"],
                "description": "The unit of temperature to use.",
            },
        },
        "required": ["location"],
    },
}

forecast_tool = {
    "name": "get_weather_forecast",
    "description": "Get up to 7-day weather forecast for the given location. The location should be a city with state/country. "
    + "Use this tool if the user needs to know the future weather/upcoming conditions for a location, e.g. if it will be rainy next week. "
    + "If the number of days is not specified, the tool will default to 7 days."
    + "The tool will return a string summarizing the forecast for the number of days specified.",
    "input_schema": {
        "type": "object",
        "properties": {
            "location": {
                "type": "string",
                "description": "The city and state/country to get the forecast for. e.g. 'New York, NY', 'San Francisco, CA', 'London, UK'",
            },
            "days": {
                "type": "integer",
                "description": "The number of days to get the forecast for (must be between 1 and 7)",
                "minimum": 1,
                "maximum": 7,
            },
        },
        "required": ["location"],
    },
}


def get_weather(location: str, unit: str = "celsiusn") -> str:
    def celsius_to_fahrenheit(celsius: float) -> float:
        return (celsius * 9 / 5) + 32

    if "San Francisco" in location:
        degrees = 15
    elif "New York" in location:
        degrees = 10
    elif "London" in location:
        degrees = 5
    else:
        return f"Weather information not available for {location}."

    if unit == "fahrenheit":
        return f"{celsius_to_fahrenheit(degrees)} degrees fahrenheit"
    else:
        return f"{degrees} degrees celsius"


def get_weather_forecast(location: str, days: int = 7) -> str:
    forcasts = {
        "San Francisco": "Mostly sunny with a chance of rain. Temperature will be around 60 degrees fahrenheit.",
        "New York": "Partly cloudy with a chance of snow. Temperature will be around 30 degrees fahrenheit.",
        "London": "Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.",
        "Seattle": "Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.",
    }
    for key in forcasts.keys():
        if key in location:
            return forcasts[key]
    return f"Forecast not available for {location}."

# %% [markdown]
# ## Tool call dispatcher

# %%
def process_tool_call(tool_name, tool_input) -> str:
    if tool_name == weather_tool["name"]:
        return get_weather(
            location=tool_input["location"],
            unit=tool_input["unit"] if "unit" in tool_input else "celsius",
        )
    elif tool_name == forecast_tool["name"]:
        return get_weather_forecast(
            location=tool_input["location"],
            days=tool_input["days"] if "days" in tool_input else 7,
        )
    else:
        return f"Error: Unknown tool name: {tool_name}."

# %% [markdown]
# ## Agent loop

# %%
# ANSI color codes
CYAN = "\033[96m"
YELLOW = "\033[93m"
GREEN = "\033[92m"
RED = "\033[91m"
RESET = "\033[0m"

# %%
def run_agent(
    user_query: str,
    client: anthropic.Anthropic,
    model: str = "claude-3-haiku-20240307",
    system_message: str | anthropic.Omit = anthropic.Omit(),
    tools: list[dict] = [],
    max_interations: int = 10,
) -> tuple[str | None, list[MessageParam]]:
    current_iteration = 0
    messages = [{"role": "user", "content": user_query}]

    while current_iteration < max_interations:
        current_iteration += 1

        print(f"{CYAN}***LOG: sending messages: {messages}{RESET}")
        response = client.messages.create(
            model=model,
            max_tokens=1024,
            tools=tools,
            messages=messages,
            system=system_message,
        )
        print(f"{CYAN}***LOG: claude response: {response}{RESET}")
        print("--------------------------------")

        messages.append({"role": "assistant", "content": response.content})

        if response.stop_reason == "tool_use":
            tool_calls = [
                content for content in response.content if content.type == "tool_use"
            ]
            tool_results = []
            for tool_call in tool_calls:
                tool_name = tool_call.name
                tool_input = tool_call.input
                tool_output = process_tool_call(tool_name, tool_input)
                print(
                    f"{YELLOW}***LOG: calling tool {tool_name} with input {tool_input}; tool output: {tool_output}{RESET}"
                )
                tool_results.append(
                    {
                        "type": "tool_result",
                        "tool_use_id": tool_call.id,
                        "content": tool_output,
                    }
                )
            tool_resp_message = {"role": "user", "content": tool_results}
            messages.append(tool_resp_message)

        elif response.stop_reason == "end_turn":
            break

        else:
            print(f"{RED}WARNING: Unexpected stop reason {response.stop_reason}{RESET}")
            break

    if current_iteration >= max_interations:
        print(f"{RED}WARNING: Max iterations reached. {RESET}")

    final_content = next(
        (content.text for content in response.content if content.type == "text"),
        None,
    )

    return final_content, messages

# %%
def test_weather(query: str):
    api_key = userdata.get("ANTHROPIC_API_KEY")
    client = anthropic.Anthropic(api_key=api_key)
    model = "claude-3-haiku-20240307"

    tools = [weather_tool, forecast_tool]
    tool_names = ", ".join(t["name"] for t in tools)
    system_message = f"""
You have access to the following tools: {tool_names}.
- ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
- Choose the right tool based on the user's query.
- When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
- For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
Include all tool calls in a single response whenever possible.
Prioritize calling tools in parallel over sequential execution whenever possible.

List of available tools: {tool_names}
    """
    print(f"system message: {system_message}")

    final_content, messages = run_agent(
        user_query=query,
        client=client,
        model=model,
        system_message=system_message,
        tools=tools,
        max_interations=10,
    )

    print()
    if final_content:
        print(f"{GREEN}Claude: {final_content}{RESET}")
    else:
        print(f"{RED}WARNING: No text response from Claude. {RESET}")

    print(f"\n{CYAN}--- CONVERSATION HISTORY ---{RESET}")
    for i, message in enumerate(messages):
        print(f"{CYAN}[{i}] {message['role']}: {message['content']}{RESET}")
    print(f"{CYAN}--- END OF CONVERSATION HISTORY ---{RESET}")

# %% [markdown]
# ## Tests

# %%
test_weather("What's weather in NYC?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in NYC?"}]
# ***LOG: claude response: Message(id='msg_011VpDaQtz9h4QfE4kfWNqTo', content=[TextBlock(citations=None, text="Okay, let's get the current weather for New York City:", type='text'), ToolUseBlock(id='toolu_01Twm8DtgJURjiM7MzqwNbrh', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=837, output_tokens=90, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'New York, NY', 'unit': 'celsius'}; tool output: 10 degrees celsius
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in NYC?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's get the current weather for New York City:", type='text'), ToolUseBlock(id='toolu_01Twm8DtgJURjiM7MzqwNbrh', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01Twm8DtgJURjiM7MzqwNbrh', 'content': '10 degrees celsius'}]}]
# ***LOG: claude response: Message(id='msg_0134exxYAByXMoooDStbX15s', content=[TextBlock(citations=None, text='The current weather in New York City is 10 degrees Celsius.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=942, output_tokens=19, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: The current weather in New York City is 10 degrees Celsius.
#
# --- CONVERSATION HISTORY ---
# [0] user: What's weather in NYC?
# [1] assistant: [TextBlock(citations=None, text="Okay, let's get the current weather for New York City:", type='text'), ToolUseBlock(id='toolu_01Twm8DtgJURjiM7MzqwNbrh', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01Twm8DtgJURjiM7MzqwNbrh', 'content': '10 degrees celsius'}]
# [3] assistant: [TextBlock(citations=None, text='The current weather in New York City is 10 degrees Celsius.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("What's weather in SFO and London?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in SFO and London?"}]
# ***LOG: claude response: Message(id='msg_01QrAL2GfHYKe2uKpbHJaLjG', content=[TextBlock(citations=None, text="Okay, let's check the current weather for both San Francisco, CA and London, UK:", type='text'), ToolUseBlock(id='toolu_01LQFKq2G764cKnf1jy7YSpV', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01Mv3eCCVAhxebJ8uKst9oCq', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=841, output_tokens=153, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'San Francisco, CA', 'unit': 'celsius'}; tool output: 15 degrees celsius
# ***LOG: calling tool get_current_weather with input {'location': 'London, UK', 'unit': 'celsius'}; tool output: 5 degrees celsius
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in SFO and London?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's check the current weather for both San Francisco, CA and London, UK:", type='text'), ToolUseBlock(id='toolu_01LQFKq2G764cKnf1jy7YSpV', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01Mv3eCCVAhxebJ8uKst9oCq', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01LQFKq2G764cKnf1jy7YSpV', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01Mv3eCCVAhxebJ8uKst9oCq', 'content': '5 degrees celsius'}]}]
# ***LOG: claude response: Message(id='msg_01K1D9Dsn1a2b4NxAKaApXgE', content=[TextBlock(citations=None, text='Based on the results, the current temperature in San Francisco, CA is 15 degrees Celsius, while in London, UK it is 5 degrees Celsius.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1068, output_tokens=39, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: Based on the results, the current temperature in San Francisco, CA is 15 degrees Celsius, while in London, UK it is 5 degrees Celsius.
#
# --- CONVERSATION HISTORY ---
# [0] user: What's weather in SFO and London?
# [1] assistant: [TextBlock(citations=None, text="Okay, let's check the current weather for both San Francisco, CA and London, UK:", type='text'), ToolUseBlock(id='toolu_01LQFKq2G764cKnf1jy7YSpV', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01Mv3eCCVAhxebJ8uKst9oCq', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01LQFKq2G764cKnf1jy7YSpV', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01Mv3eCCVAhxebJ8uKst9oCq', 'content': '5 degrees celsius'}]
# [3] assistant: [TextBlock(citations=None, text='Based on the results, the current temperature in San Francisco, CA is 15 degrees Celsius, while in London, UK it is 5 degrees Celsius.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("What's 2+2?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's 2+2?"}]
# ***LOG: claude response: Message(id='msg_01Q3Bs4hTMGhDSG4w2xu2mFM', content=[TextBlock(citations=None, text='4.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=838, output_tokens=6, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: 4.
#
# --- CONVERSATION HISTORY ---
# [0] user: What's 2+2?
# [1] assistant: [TextBlock(citations=None, text='4.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("What's capital of France?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's capital of France?"}]
# ***LOG: claude response: Message(id='msg_01A5SNQ1TGBrAMYByV1Av1W7', content=[TextBlock(citations=None, text='The capital of France is Paris.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=837, output_tokens=10, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: The capital of France is Paris.
#
# --- CONVERSATION HISTORY ---
# [0] user: What's capital of France?
# [1] assistant: [TextBlock(citations=None, text='The capital of France is Paris.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("Compare weather of 3 cities: SFO, NYC and London")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': 'Compare weather of 3 cities: SFO, NYC and London'}]
# ***LOG: claude response: Message(id='msg_01F3aLA72GBEXtUCZRbjBY9m', content=[TextBlock(citations=None, text="Okay, let's compare the weather for the 3 cities you requested - San Francisco (SFO), New York City (NYC), and London:", type='text'), ToolUseBlock(id='toolu_01Jr54BFLxa2rtRedhNaqiyH', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01DiskhbaSJJHacdavQK8SvH', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01YJsharecSnSLoNsSArx4Lb', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=846, output_tokens=224, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'San Francisco, CA', 'unit': 'celsius'}; tool output: 15 degrees celsius
# ***LOG: calling tool get_current_weather with input {'location': 'New York, NY', 'unit': 'celsius'}; tool output: 10 degrees celsius
# ***LOG: calling tool get_current_weather with input {'location': 'London, UK', 'unit': 'celsius'}; tool output: 5 degrees celsius
# ***LOG: sending messages: [{'role': 'user', 'content': 'Compare weather of 3 cities: SFO, NYC and London'}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's compare the weather for the 3 cities you requested - San Francisco (SFO), New York City (NYC), and London:", type='text'), ToolUseBlock(id='toolu_01Jr54BFLxa2rtRedhNaqiyH', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01DiskhbaSJJHacdavQK8SvH', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01YJsharecSnSLoNsSArx4Lb', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01Jr54BFLxa2rtRedhNaqiyH', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01DiskhbaSJJHacdavQK8SvH', 'content': '10 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01YJsharecSnSLoNsSArx4Lb', 'content': '5 degrees celsius'}]}]
# ***LOG: claude response: Message(id='msg_012p5jcp6uAiHesqtPqzukRc', content=[TextBlock(citations=None, text="Based on the current weather information, we can see that:\n- San Francisco is currently 15°C\n- New York City is currently 10°C \n- London is currently 5°C\n\nSo San Francisco is the warmest of the three cities right now, while London is the coolest.\n\nLet's also look at the 7-day weather forecast for each city:", type='text'), ToolUseBlock(id='toolu_01XPsQMnq87bPq95pUCkYSNX', input={'location': 'San Francisco, CA'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01QUV3MonJqFdqscaHmYvRvd', input={'location': 'New York, NY'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01KSrkWCRZMGeqePyfhjAawC', input={'location': 'London, UK'}, name='get_weather_forecast', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1175, output_tokens=223, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_weather_forecast with input {'location': 'San Francisco, CA'}; tool output: Mostly sunny with a chance of rain. Temperature will be around 60 degrees fahrenheit.
# ***LOG: calling tool get_weather_forecast with input {'location': 'New York, NY'}; tool output: Partly cloudy with a chance of snow. Temperature will be around 30 degrees fahrenheit.
# ***LOG: calling tool get_weather_forecast with input {'location': 'London, UK'}; tool output: Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.
# ***LOG: sending messages: [{'role': 'user', 'content': 'Compare weather of 3 cities: SFO, NYC and London'}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's compare the weather for the 3 cities you requested - San Francisco (SFO), New York City (NYC), and London:", type='text'), ToolUseBlock(id='toolu_01Jr54BFLxa2rtRedhNaqiyH', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01DiskhbaSJJHacdavQK8SvH', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01YJsharecSnSLoNsSArx4Lb', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01Jr54BFLxa2rtRedhNaqiyH', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01DiskhbaSJJHacdavQK8SvH', 'content': '10 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01YJsharecSnSLoNsSArx4Lb', 'content': '5 degrees celsius'}]}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Based on the current weather information, we can see that:\n- San Francisco is currently 15°C\n- New York City is currently 10°C \n- London is currently 5°C\n\nSo San Francisco is the warmest of the three cities right now, while London is the coolest.\n\nLet's also look at the 7-day weather forecast for each city:", type='text'), ToolUseBlock(id='toolu_01XPsQMnq87bPq95pUCkYSNX', input={'location': 'San Francisco, CA'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01QUV3MonJqFdqscaHmYvRvd', input={'location': 'New York, NY'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01KSrkWCRZMGeqePyfhjAawC', input={'location': 'London, UK'}, name='get_weather_forecast', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01XPsQMnq87bPq95pUCkYSNX', 'content': 'Mostly sunny with a chance of rain. Temperature will be around 60 degrees fahrenheit.'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01QUV3MonJqFdqscaHmYvRvd', 'content': 'Partly cloudy with a chance of snow. Temperature will be around 30 degrees fahrenheit.'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01KSrkWCRZMGeqePyfhjAawC', 'content': 'Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.'}]}]
# ***LOG: claude response: Message(id='msg_019cJHLrNpns4RGtLwJc1gJW', content=[TextBlock(citations=None, text='The 7-day forecast shows:\n- San Francisco will be mostly sunny with a chance of rain, around 60°F\n- New York City will be partly cloudy with a chance of snow, around 30°F\n- London will be cloudy with a chance of rain, around 40°F\n\nSo in summary, San Francisco seems to be the warmest and sunniest of the three cities currently, while London is the coolest and cloudiest. The forecast also indicates different weather patterns across the three locations over the next week.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1549, output_tokens=119, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: The 7-day forecast shows:
# - San Francisco will be mostly sunny with a chance of rain, around 60°F
# - New York City will be partly cloudy with a chance of snow, around 30°F
# - London will be cloudy with a chance of rain, around 40°F
#
# So in summary, San Francisco seems to be the warmest and sunniest of the three cities currently, while London is the coolest and cloudiest. The forecast also indicates different weather patterns across the three locations over the next week.
#
# --- CONVERSATION HISTORY ---
# [0] user: Compare weather of 3 cities: SFO, NYC and London
# [1] assistant: [TextBlock(citations=None, text="Okay, let's compare the weather for the 3 cities you requested - San Francisco (SFO), New York City (NYC), and London:", type='text'), ToolUseBlock(id='toolu_01Jr54BFLxa2rtRedhNaqiyH', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01DiskhbaSJJHacdavQK8SvH', input={'location': 'New York, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01YJsharecSnSLoNsSArx4Lb', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01Jr54BFLxa2rtRedhNaqiyH', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01DiskhbaSJJHacdavQK8SvH', 'content': '10 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01YJsharecSnSLoNsSArx4Lb', 'content': '5 degrees celsius'}]
# [3] assistant: [TextBlock(citations=None, text="Based on the current weather information, we can see that:\n- San Francisco is currently 15°C\n- New York City is currently 10°C \n- London is currently 5°C\n\nSo San Francisco is the warmest of the three cities right now, while London is the coolest.\n\nLet's also look at the 7-day weather forecast for each city:", type='text'), ToolUseBlock(id='toolu_01XPsQMnq87bPq95pUCkYSNX', input={'location': 'San Francisco, CA'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01QUV3MonJqFdqscaHmYvRvd', input={'location': 'New York, NY'}, name='get_weather_forecast', type='tool_use'), ToolUseBlock(id='toolu_01KSrkWCRZMGeqePyfhjAawC', input={'location': 'London, UK'}, name='get_weather_forecast', type='tool_use')]
# [4] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01XPsQMnq87bPq95pUCkYSNX', 'content': 'Mostly sunny with a chance of rain. Temperature will be around 60 degrees fahrenheit.'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01QUV3MonJqFdqscaHmYvRvd', 'content': 'Partly cloudy with a chance of snow. Temperature will be around 30 degrees fahrenheit.'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01KSrkWCRZMGeqePyfhjAawC', 'content': 'Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.'}]
# [5] assistant: [TextBlock(citations=None, text='The 7-day forecast shows:\n- San Francisco will be mostly sunny with a chance of rain, around 60°F\n- New York City will be partly cloudy with a chance of snow, around 30°F\n- London will be cloudy with a chance of rain, around 40°F\n\nSo in summary, San Francisco seems to be the warmest and sunniest of the three cities currently, while London is the coolest and cloudiest. The forecast also indicates different weather patterns across the three locations over the next week.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("Is is warmer now in SF or NYC?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': 'Is is warmer now in SF or NYC?'}]
# ***LOG: claude response: Message(id='msg_016paoBKdo29pSm5mpHi1Z22', content=[TextBlock(citations=None, text='To compare the current weather in San Francisco (SF) and New York City (NYC), I will use the following tool:', type='text'), ToolUseBlock(id='toolu_019S2pvhoEF5AWnyd8go7ZHS', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01CGxqgv9UiJkhJ35rmSD5Yx', input={'location': 'New York City, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=841, output_tokens=160, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'San Francisco, CA', 'unit': 'celsius'}; tool output: 15 degrees celsius
# ***LOG: calling tool get_current_weather with input {'location': 'New York City, NY', 'unit': 'celsius'}; tool output: 10 degrees celsius
# ***LOG: sending messages: [{'role': 'user', 'content': 'Is is warmer now in SF or NYC?'}, {'role': 'assistant', 'content': [TextBlock(citations=None, text='To compare the current weather in San Francisco (SF) and New York City (NYC), I will use the following tool:', type='text'), ToolUseBlock(id='toolu_019S2pvhoEF5AWnyd8go7ZHS', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01CGxqgv9UiJkhJ35rmSD5Yx', input={'location': 'New York City, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_019S2pvhoEF5AWnyd8go7ZHS', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01CGxqgv9UiJkhJ35rmSD5Yx', 'content': '10 degrees celsius'}]}]
# ***LOG: claude response: Message(id='msg_018WGfRqUbVGAfHP4MZvKD6K', content=[TextBlock(citations=None, text='Based on the current weather data, it is currently warmer in San Francisco (15°C) compared to New York City (10°C). So it is warmer now in SF than NYC.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1075, output_tokens=45, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: Based on the current weather data, it is currently warmer in San Francisco (15°C) compared to New York City (10°C). So it is warmer now in SF than NYC.
#
# --- CONVERSATION HISTORY ---
# [0] user: Is is warmer now in SF or NYC?
# [1] assistant: [TextBlock(citations=None, text='To compare the current weather in San Francisco (SF) and New York City (NYC), I will use the following tool:', type='text'), ToolUseBlock(id='toolu_019S2pvhoEF5AWnyd8go7ZHS', input={'location': 'San Francisco, CA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use'), ToolUseBlock(id='toolu_01CGxqgv9UiJkhJ35rmSD5Yx', input={'location': 'New York City, NY', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_019S2pvhoEF5AWnyd8go7ZHS', 'content': '15 degrees celsius'}, {'type': 'tool_result', 'tool_use_id': 'toolu_01CGxqgv9UiJkhJ35rmSD5Yx', 'content': '10 degrees celsius'}]
# [3] assistant: [TextBlock(citations=None, text='Based on the current weather data, it is currently warmer in San Francisco (15°C) compared to New York City (10°C). So it is warmer now in SF than NYC.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("What's weather in Seattle?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in Seattle?"}]
# ***LOG: claude response: Message(id='msg_01XPiwjBBhXYw5dbi2tLroRb', content=[TextBlock(citations=None, text='Okay, let me check the weather in Seattle for you:', type='text'), ToolUseBlock(id='toolu_01QuxcvErbxDVruyNCK49koM', input={'location': 'Seattle, WA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=837, output_tokens=89, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'Seattle, WA', 'unit': 'celsius'}; tool output: Weather information not available for Seattle, WA.
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in Seattle?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text='Okay, let me check the weather in Seattle for you:', type='text'), ToolUseBlock(id='toolu_01QuxcvErbxDVruyNCK49koM', input={'location': 'Seattle, WA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01QuxcvErbxDVruyNCK49koM', 'content': 'Weather information not available for Seattle, WA.'}]}]
# ***LOG: claude response: Message(id='msg_01ULuD6N3Yi948L9ZiJz73sd', content=[TextBlock(citations=None, text="It looks like I wasn't able to retrieve the current weather for Seattle. Let me try getting the weather forecast instead:", type='text'), ToolUseBlock(id='toolu_01QTxznnrjRtpYrP93MMi3oR', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=946, output_tokens=101, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_weather_forecast with input {'location': 'Seattle, WA', 'days': 7}; tool output: Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.
# ***LOG: sending messages: [{'role': 'user', 'content': "What's weather in Seattle?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text='Okay, let me check the weather in Seattle for you:', type='text'), ToolUseBlock(id='toolu_01QuxcvErbxDVruyNCK49koM', input={'location': 'Seattle, WA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01QuxcvErbxDVruyNCK49koM', 'content': 'Weather information not available for Seattle, WA.'}]}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="It looks like I wasn't able to retrieve the current weather for Seattle. Let me try getting the weather forecast instead:", type='text'), ToolUseBlock(id='toolu_01QTxznnrjRtpYrP93MMi3oR', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01QTxznnrjRtpYrP93MMi3oR', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]}]
# ***LOG: claude response: Message(id='msg_01R88vLRiwLouhtHdyTrodTH', content=[TextBlock(citations=None, text='Based on the 7-day weather forecast, it looks like the weather in Seattle will be rainy with a chance of snow, and the temperature will be around 50 degrees Fahrenheit. Let me know if you need any other details!', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1077, output_tokens=55, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: Based on the 7-day weather forecast, it looks like the weather in Seattle will be rainy with a chance of snow, and the temperature will be around 50 degrees Fahrenheit. Let me know if you need any other details!
#
# --- CONVERSATION HISTORY ---
# [0] user: What's weather in Seattle?
# [1] assistant: [TextBlock(citations=None, text='Okay, let me check the weather in Seattle for you:', type='text'), ToolUseBlock(id='toolu_01QuxcvErbxDVruyNCK49koM', input={'location': 'Seattle, WA', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01QuxcvErbxDVruyNCK49koM', 'content': 'Weather information not available for Seattle, WA.'}]
# [3] assistant: [TextBlock(citations=None, text="It looks like I wasn't able to retrieve the current weather for Seattle. Let me try getting the weather forecast instead:", type='text'), ToolUseBlock(id='toolu_01QTxznnrjRtpYrP93MMi3oR', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')]
# [4] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01QTxznnrjRtpYrP93MMi3oR', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]
# [5] assistant: [TextBlock(citations=None, text='Based on the 7-day weather forecast, it looks like the weather in Seattle will be rainy with a chance of snow, and the temperature will be around 50 degrees Fahrenheit. Let me know if you need any other details!', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("Will it rain next week in Seattle?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': 'Will it rain next week in Seattle?'}]
# ***LOG: claude response: Message(id='msg_01BncoDa84gNj1wpkKHjLxEu', content=[TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle next week:", type='text'), ToolUseBlock(id='toolu_01SQJYKSQAL4QWLA4AkTbbYG', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=839, output_tokens=90, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_weather_forecast with input {'location': 'Seattle, WA', 'days': 7}; tool output: Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.
# ***LOG: sending messages: [{'role': 'user', 'content': 'Will it rain next week in Seattle?'}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle next week:", type='text'), ToolUseBlock(id='toolu_01SQJYKSQAL4QWLA4AkTbbYG', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01SQJYKSQAL4QWLA4AkTbbYG', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]}]
# ***LOG: claude response: Message(id='msg_01WauZCwRw2fsuj46McfW5u7', content=[TextBlock(citations=None, text='Based on the 7-day weather forecast for Seattle, it looks like there is a good chance of rain next week. The weather summary indicates rainy conditions with a possibility of some snow as well. The temperatures are expected to be around 50°F. So it seems likely that it will rain in Seattle next week.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=959, output_tokens=70, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: Based on the 7-day weather forecast for Seattle, it looks like there is a good chance of rain next week. The weather summary indicates rainy conditions with a possibility of some snow as well. The temperatures are expected to be around 50°F. So it seems likely that it will rain in Seattle next week.
#
# --- CONVERSATION HISTORY ---
# [0] user: Will it rain next week in Seattle?
# [1] assistant: [TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle next week:", type='text'), ToolUseBlock(id='toolu_01SQJYKSQAL4QWLA4AkTbbYG', input={'location': 'Seattle, WA', 'days': 7}, name='get_weather_forecast', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01SQJYKSQAL4QWLA4AkTbbYG', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]
# [3] assistant: [TextBlock(citations=None, text='Based on the 7-day weather forecast for Seattle, it looks like there is a good chance of rain next week. The weather summary indicates rainy conditions with a possibility of some snow as well. The temperatures are expected to be around 50°F. So it seems likely that it will rain in Seattle next week.', type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("What's the weather now in London, and will it rain next week?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': "What's the weather now in London, and will it rain next week?"}]
# ***LOG: claude response: Message(id='msg_01XYS4kvRSEduxiJ8U9w7zmL', content=[TextBlock(citations=None, text="Okay, let's check the current weather and forecast for London:", type='text'), ToolUseBlock(id='toolu_014DyVAP4MYNTe6GaFYTSDNN', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=846, output_tokens=89, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_current_weather with input {'location': 'London, UK', 'unit': 'celsius'}; tool output: 5 degrees celsius
# ***LOG: sending messages: [{'role': 'user', 'content': "What's the weather now in London, and will it rain next week?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's check the current weather and forecast for London:", type='text'), ToolUseBlock(id='toolu_014DyVAP4MYNTe6GaFYTSDNN', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_014DyVAP4MYNTe6GaFYTSDNN', 'content': '5 degrees celsius'}]}]
# ***LOG: claude response: Message(id='msg_01Dh32QNKWyQFYj5h861jwbK', content=[ToolUseBlock(id='toolu_01PtQn2cMDmZoBCTQdJtLwkY', input={'location': 'London, UK', 'days': 7}, name='get_weather_forecast', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=950, output_tokens=75, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_weather_forecast with input {'location': 'London, UK', 'days': 7}; tool output: Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.
# ***LOG: sending messages: [{'role': 'user', 'content': "What's the weather now in London, and will it rain next week?"}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's check the current weather and forecast for London:", type='text'), ToolUseBlock(id='toolu_014DyVAP4MYNTe6GaFYTSDNN', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_014DyVAP4MYNTe6GaFYTSDNN', 'content': '5 degrees celsius'}]}, {'role': 'assistant', 'content': [ToolUseBlock(id='toolu_01PtQn2cMDmZoBCTQdJtLwkY', input={'location': 'London, UK', 'days': 7}, name='get_weather_forecast', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01PtQn2cMDmZoBCTQdJtLwkY', 'content': 'Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.'}]}]
# ***LOG: claude response: Message(id='msg_01FsFCskmZUG5AyCJJt2jsVR', content=[TextBlock(citations=None, text="The current temperature in London is 5 degrees celsius. Looking at the 7-day forecast, it seems it will be cloudy with a chance of rain, with temperatures around 40 degrees fahrenheit. So it does look like there's a possibility of rain in the upcoming week in London.", type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=1055, output_tokens=66, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: The current temperature in London is 5 degrees celsius. Looking at the 7-day forecast, it seems it will be cloudy with a chance of rain, with temperatures around 40 degrees fahrenheit. So it does look like there's a possibility of rain in the upcoming week in London.
#
# --- CONVERSATION HISTORY ---
# [0] user: What's the weather now in London, and will it rain next week?
# [1] assistant: [TextBlock(citations=None, text="Okay, let's check the current weather and forecast for London:", type='text'), ToolUseBlock(id='toolu_014DyVAP4MYNTe6GaFYTSDNN', input={'location': 'London, UK', 'unit': 'celsius'}, name='get_current_weather', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_014DyVAP4MYNTe6GaFYTSDNN', 'content': '5 degrees celsius'}]
# [3] assistant: [ToolUseBlock(id='toolu_01PtQn2cMDmZoBCTQdJtLwkY', input={'location': 'London, UK', 'days': 7}, name='get_weather_forecast', type='tool_use')]
# [4] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01PtQn2cMDmZoBCTQdJtLwkY', 'content': 'Cloudy with a chance of rain. Temperature will be around 40 degrees fahrenheit.'}]
# [5] assistant: [TextBlock(citations=None, text="The current temperature in London is 5 degrees celsius. Looking at the 7-day forecast, it seems it will be cloudy with a chance of rain, with temperatures around 40 degrees fahrenheit. So it does look like there's a possibility of rain in the upcoming week in London.", type='text')]
# --- END OF CONVERSATION HISTORY ---

# %%
test_weather("Should I bring an umbrella to Seattle the day after tomorrow?")
# Out:
# system message:
# You have access to the following tools: get_current_weather, get_weather_forecast.
# - ONLY use the tools listed above. DO NOT call any other tools that are not available to you.
# - Choose the right tool based on the user's query.
# - When no appropriate tool is available, respond directly with your own knowledge and expertise without invoking any tools.
# - For maximum efficiency, whenever you perform multiple independent operations, invoke all relevant tools simultaneously rather than sequentially.
# Include all tool calls in a single response whenever possible.
# Prioritize calling tools in parallel over sequential execution whenever possible.
#
# List of available tools: get_current_weather, get_weather_forecast
#
# ***LOG: sending messages: [{'role': 'user', 'content': 'Should I bring an umbrella to Seattle the day after tomorrow?'}]
# ***LOG: claude response: Message(id='msg_011xjReSkidpKcUFkFgeNhYY', content=[TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle to see if you should bring an umbrella the day after tomorrow:", type='text'), ToolUseBlock(id='toolu_01BzbRottpXG4QHvzmwznn8z', input={'location': 'Seattle, WA', 'days': 2}, name='get_weather_forecast', type='tool_use')], model='claude-3-haiku-20240307', role='assistant', stop_reason='tool_use', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=844, output_tokens=101, server_tool_use=None, service_tier='standard'))
# --------------------------------
# ***LOG: calling tool get_weather_forecast with input {'location': 'Seattle, WA', 'days': 2}; tool output: Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.
# ***LOG: sending messages: [{'role': 'user', 'content': 'Should I bring an umbrella to Seattle the day after tomorrow?'}, {'role': 'assistant', 'content': [TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle to see if you should bring an umbrella the day after tomorrow:", type='text'), ToolUseBlock(id='toolu_01BzbRottpXG4QHvzmwznn8z', input={'location': 'Seattle, WA', 'days': 2}, name='get_weather_forecast', type='tool_use')]}, {'role': 'user', 'content': [{'type': 'tool_result', 'tool_use_id': 'toolu_01BzbRottpXG4QHvzmwznn8z', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]}]
# ***LOG: claude response: Message(id='msg_01BTdbcg7TFuJ9ycTUUEms6r', content=[TextBlock(citations=None, text='Based on the 2-day weather forecast for Seattle, it looks like you should plan to bring an umbrella with you the day after tomorrow. The forecast is calling for rain, so an umbrella would be a good idea to have.', type='text')], model='claude-3-haiku-20240307', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=975, output_tokens=53, server_tool_use=None, service_tier='standard'))
# --------------------------------
#
# Claude: Based on the 2-day weather forecast for Seattle, it looks like you should plan to bring an umbrella with you the day after tomorrow. The forecast is calling for rain, so an umbrella would be a good idea to have.
#
# --- CONVERSATION HISTORY ---
# [0] user: Should I bring an umbrella to Seattle the day after tomorrow?
# [1] assistant: [TextBlock(citations=None, text="Okay, let's check the weather forecast for Seattle to see if you should bring an umbrella the day after tomorrow:", type='text'), ToolUseBlock(id='toolu_01BzbRottpXG4QHvzmwznn8z', input={'location': 'Seattle, WA', 'days': 2}, name='get_weather_forecast', type='tool_use')]
# [2] user: [{'type': 'tool_result', 'tool_use_id': 'toolu_01BzbRottpXG4QHvzmwznn8z', 'content': 'Rainy with a chance of snow. Temperature will be around 50 degrees fahrenheit.'}]
# [3] assistant: [TextBlock(citations=None, text='Based on the 2-day weather forecast for Seattle, it looks like you should plan to bring an umbrella with you the day after tomorrow. The forecast is calling for rain, so an umbrella would be a good idea to have.', type='text')]
# --- END OF CONVERSATION HISTORY ---
